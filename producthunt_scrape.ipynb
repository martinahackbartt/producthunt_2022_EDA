# %% [markdown]
# ## Data extraction of Product Hunt data using Beautiful Soup

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import pandas as pd

# %% [markdown]
# My workflow on this web scraping process consists of 3 steps
# 1. Creating the whole scraping process for a unique URL (a single day of the year)
# 2. Extrapolating to the next days by setting a base URL and iterating over the day and month
# 3. Merging the results into 1 dataframe

# %% [markdown]
# STEP 1: Scraping process for unique URL

# %%
# Making a request to the website
url = 'https://www.producthunt.com/time-travel/2022/1/1'
data = requests.get(url)
# Parsing the HTML of the page
soup = BeautifulSoup(data.content, 'html.parser')
#print(soup.prettify())

# %%
# Find all the elements of the class to extract all posts
post_containers = soup.find_all(class_='styles_item__T_iXF')
#print(post_containers)

# %%
# Loop through each post container
data= []   
for container in post_containers:
    # Extract the name of the product
    product_name= container.find(class_="styles_font__m46I_ styles_medium__pDQUU styles_semiBold__yhRqL styles_title__MqCmH styles_lineHeight__kGlRn styles_underline__IqHIA").text
    # Extract the number of upvotes
    upvotes= container.find(class_="styles_font__m46I_ styles_black__Z9fG_ styles_small__lLD08 styles_semiBold__yhRqL styles_lineHeight__kGlRn styles_underline__IqHIA").text
    # Extract the category
    category= container.find(class_="styles_postTopicLink__9NDtt")
    if category is not None:
        category = category.text
    else:
        category = "N/A"
    # Extract the tagline
    tagline= container.find(class_= "styles_font__m46I_ styles_grey__YlBrh styles_small__lLD08 styles_normal__FGFK7 styles_tagline__i9xwM styles_lineHeight__kGlRn").text
    # Extract the number of comments
    comments= container.find(class_="styles_button__9iLfH styles_smallSize__n7oLn styles_subtleVariant__qmS4e styles_simpleVariant__63ULX styles_button__dtE4Y").text
    # Extract the image link
    image= container.find(class_="styles_mediaThumbnail__LDCQN")
    image_link = image.get('src')
    # Extract the pricing
    pricing= container.find(class_="styles_font__m46I_ styles_black__Z9fG_ styles_xSmall__xeHkB styles_normal__FGFK7 styles_pricingType__EdAeQ styles_siblingTopicTag__wQEbN styles_lineHeight__kGlRn styles_underline__IqHIA")
    if pricing is not None:
        pricing = pricing.text
    else:
        pricing = "N/A"
    # Store the data in a dictionary
    post_data = {
        'product_name': product_name,
        'upvotes': upvotes,
        'category': category,
        'tagline': tagline,
        'comments': comments,
        'image_src': image_link,
        'pricing': pricing
        }
    # Add the dictionary to the list
    data.append(post_data)
    # Create a Pandas DataFrame from the list of dictionaries
    df = pd.DataFrame(data)

# %%
# Add a column with the product's position
df['position'] = range(1, len(df)+1)

#Add a column with the 'date' (which is actually the title)
# Extract the title of the page
page_title = soup.title.string
# Add a new column to the DataFrame
df['date'] = page_title
# Set the value of the 'page_title' column for all rows to the page title
df['date'] = df['date'].apply(lambda x: page_title)

# Print the DataFrame
display(df)
# Out:
#                         product_name upvotes          category  \
# 0   World Explorer by Insured Nomads     389      Global Nomad
# 1               Tailwind Box Shadows     203      Productivity
# 2      24me Smart Personal Assistant     127      Productivity
# 3                 Habitify Challenge     168      Productivity
# 4                  Sunflower iOS App     108               iOS
# 5                  Best Stoic Quotes      95      Productivity
# 6      2021 Code Stats from WakaTime      90      Productivity
# 7                           Octolink      75           Web App
# 8                               Lume      83   Developer Tools
# 9                My Good First Issue      56       Open Source
# 10                        pppixelate      46           Web App
# 11                            Kaashi      31           Android
# 12                              Vers      34  Health & Fitness
# 13                    PHUBLIC DOMAIN      45               Art
# 14                           Clanica      39             Email
# 15                          Skeleton      17           Windows
# 16                    Share My Image      21      Productivity
#
#                                               tagline comments  \
# 0   Insurance meets travel tech for the global wor...       84
# 1   Curated list of box shadows for your cards to ...       25
# 2   Keep new year's resolutions and get organized ...        8
# 3   Track & build new habits with your friends in ...       10
# 4   Rewire your brain to associate sobriety with r...       14
# 5       Get inspired for the new year by these quotes       10
# 6   Most used languages, editors and stats of deve...        3
# 7                Link sharing for GitHub repositories       16
# 8                    A static site generator for Deno        3
# 9    Find open source projects by the percentage o...        3
# 10       Draw pixel art and turn it into SVG patterns        3
# 11                               A Reddit alternative        4
# 12  New Year. New Social. Helping you be in the re...        3
# 13  They flipped the punks. We flip public domain ...        4
# 14                    A robust Email delivery service        2
# 15  Simply display any website as customizable ove...        0
# 16    image hosting that can be used in multiple ways        0
#
#                                             image_src           pricing  \
# 0   https://ph-files.imgix.net/9bc773c8-1720-45b6-...               N/A
# 1   https://ph-files.imgix.net/f182991d-f034-43b8-...              Free
# 2   https://ph-files.imgix.net/9afadb00-151b-4f19-...              Free
# 3   https://ph-files.imgix.net/8941b193-9073-4864-...              Free
# 4   https://ph-files.imgix.net/35f3ef3a-3a39-49b3-...              Free
# 5   https://ph-files.imgix.net/21d2e305-00a8-4ede-...              Free
# 6   https://ph-files.imgix.net/1cefa132-0cbe-468b-...              Free
# 7   https://ph-files.imgix.net/06367585-6044-4268-...              Free
# 8   https://ph-files.imgix.net/3f2582d8-972e-4a9b-...              Free
# 9   https://ph-files.imgix.net/450d3778-285e-4254-...              Free
# 10  https://ph-files.imgix.net/32abfbc6-2c74-49c4-...              Free
# 11  https://ph-files.imgix.net/9a37a568-5c65-4fdd-...              Free
# 12                                               None      Free Options
# 13  https://ph-files.imgix.net/47b61df7-cfe3-40c7-...  Payment Required
# 14  https://ph-files.imgix.net/b74c4635-5a85-4c74-...      Free Options
# 15  https://ph-files.imgix.net/16b17f27-9ae5-45ab-...              Free
# 16  https://ph-files.imgix.net/db6b8017-36ac-410a-...      Free Options
#
#     position                                               date
# 0          1   Posts for January 1, 2022 | Product Hunt | Pr...
# 1          2   Posts for January 1, 2022 | Product Hunt | Pr...
# 2          3   Posts for January 1, 2022 | Product Hunt | Pr...
# 3          4   Posts for January 1, 2022 | Product Hunt | Pr...
# 4          5   Posts for January 1, 2022 | Product Hunt | Pr...
# 5          6   Posts for January 1, 2022 | Product Hunt | Pr...
# 6          7   Posts for January 1, 2022 | Product Hunt | Pr...
# 7          8   Posts for January 1, 2022 | Product Hunt | Pr...
# 8          9   Posts for January 1, 2022 | Product Hunt | Pr...
# 9         10   Posts for January 1, 2022 | Product Hunt | Pr...
# 10        11   Posts for January 1, 2022 | Product Hunt | Pr...
# 11        12   Posts for January 1, 2022 | Product Hunt | Pr...
# 12        13   Posts for January 1, 2022 | Product Hunt | Pr...
# 13        14   Posts for January 1, 2022 | Product Hunt | Pr...
# 14        15   Posts for January 1, 2022 | Product Hunt | Pr...
# 15        16   Posts for January 1, 2022 | Product Hunt | Pr...
# 16        17   Posts for January 1, 2022 | Product Hunt | Pr...

# %% [markdown]
# STEPS 2 and 3: Scraping of data from multiple URL's by iteration of day and month and concatenation of the results in one dataframe

# %%
#Defining the main function
def scrape_data(url):
    data = requests.get(url)
    soup = BeautifulSoup(data.content, 'html.parser')
    data_= []
    post_containers = soup.find_all(class_='styles_item__T_iXF')
    #Iterating over each container
    for container in post_containers:
        # Extracting all fields from each container
        product_name= container.find(class_="styles_font__m46I_ styles_medium__pDQUU styles_semiBold__yhRqL styles_title__MqCmH styles_lineHeight__kGlRn styles_underline__IqHIA").text
        upvotes= container.find(class_="styles_font__m46I_ styles_black__Z9fG_ styles_small__lLD08 styles_semiBold__yhRqL styles_lineHeight__kGlRn styles_underline__IqHIA").text
        category= container.find(class_="styles_postTopicLink__9NDtt")
        if category is not None:
            category = category.text
        else:
            category = "N/A"
        tagline= container.find(class_= "styles_font__m46I_ styles_grey__YlBrh styles_small__lLD08 styles_normal__FGFK7 styles_tagline__i9xwM styles_lineHeight__kGlRn").text
        comments= container.find(class_="styles_button__9iLfH styles_smallSize__n7oLn styles_subtleVariant__qmS4e styles_simpleVariant__63ULX styles_button__dtE4Y").text
        image= container.find(class_="styles_mediaThumbnail__LDCQN")
        if image is not None:
            image_link = image.get('src')
        else:
            image_link = "N/A"
        pricing= container.find(class_="styles_font__m46I_ styles_black__Z9fG_ styles_xSmall__xeHkB styles_normal__FGFK7 styles_pricingType__EdAeQ styles_siblingTopicTag__wQEbN styles_lineHeight__kGlRn styles_underline__IqHIA")
        if pricing is not None:
            pricing = pricing.text
        else:
            pricing = "N/A"
        # Storing the data in a dictionary
        post_data = {
        'product_name': product_name,
        'upvotes': upvotes,
        'category': category,
        'tagline': tagline,
        'comments': comments,
        'image link': image_link,
        'pricing': pricing
        }
        # Add the dictionary to the list
        data_.append(post_data)
        # Create a Pandas DataFrame from the list of dictionaries
        df = pd.DataFrame(data_)
    # Add a column with the product's position
    df['position'] = range(1, len(df)+1)
    #Add a column with the 'date' (which is actually the title)
    # Extract the title of the page
    page_title = soup.title.string
    # Add a new column to the DataFrame
    df['date'] = page_title
    # Set the value of the 'page_title' column for all rows to the page title
    df['date'] = df['date'].apply(lambda x: page_title)
    return df

# %%
# Set the base URL for the pages
base_url = "https://www.producthunt.com/time-travel/2022/"

# Initialize an empty list to store the dataframes
df_list = []

# Set the range of months and days to iterate over, bearing into account months with 28, 30 and 31 days. 
for month in range(1, 13):
    # Set the number of days in each month
    if month in [1, 3, 5, 7, 8, 10, 12]:
        num_days = 31
# https://www.producthunt.com/time-travel/2022/12/30
# https://www.producthunt.com/time-travel/2022/12/31

# %%
final_df.reset_index(inplace=True, drop=True) 
display(final_df)
# Out:
#                           product_name upvotes      category  \
# 0     World Explorer by Insured Nomads     389  Global Nomad
# 1                 Tailwind Box Shadows     203  Productivity
# 2        24me Smart Personal Assistant     127  Productivity
# 3                   Habitify Challenge     168  Productivity
# 4                    Sunflower iOS App     108           iOS
# ...                                ...     ...           ...
# 6602                      Cloud Rebels      25          Tech
# 6603                    SuenaGringo AI      24  Productivity
# 6604              Gmax CRM Open Source      23  Productivity
# 6605  Grocery Delivery App Development      18  Productivity
# 6606                          ABV Calc      17  Spreadsheets
#
#                                                 tagline comments  \
# 0     Insurance meets travel tech for the global wor...       84
# 1     Curated list of box shadows for your cards to ...       25
# 2     Keep new year's resolutions and get organized ...        8
# 3     Track & build new habits with your friends in ...       10
# 4     Rewire your brain to associate sobriety with r...       14
# ...                                                 ...      ...
# 6602                           IT has never been easier        1
# 6603  Helps Spanish immigrants write natural & engag...        5
# 6604      Gmax CRM is an open source invoicing software        2
# 6605       SpotnEats developing customized apps for you        2
# 6606  Calculate your drink’s ABV with this handy cal...        1
#
#                                              image link           pricing  \
# 0     https://ph-files.imgix.net/9bc773c8-1720-45b6-...               N/A
# 1     https://ph-files.imgix.net/f182991d-f034-43b8-...              Free
# 2     https://ph-files.imgix.net/9afadb00-151b-4f19-...              Free
# 3     https://ph-files.imgix.net/8941b193-9073-4864-...              Free
# 4     https://ph-files.imgix.net/35f3ef3a-3a39-49b3-...              Free
# ...                                                 ...               ...
# 6602  https://ph-files.imgix.net/a1da6bb2-796c-4020-...  Payment Required
# 6603  https://ph-files.imgix.net/ab8126a3-206e-483c-...      Free Options
# 6604  https://ph-files.imgix.net/90f32823-fb61-4b22-...              Free
# 6605  https://ph-files.imgix.net/96b9a8f3-459b-4557-...  Payment Required
# 6606                                               None              Free
#
#       position                                               date
# 0            1   Posts for January 1, 2022 | Product Hunt | Pr...
# 1            2   Posts for January 1, 2022 | Product Hunt | Pr...
# 2            3   Posts for January 1, 2022 | Product Hunt | Pr...
# 3            4   Posts for January 1, 2022 | Product Hunt | Pr...
# 4            5   Posts for January 1, 2022 | Product Hunt | Pr...
# ...        ...                                                ...
# 6602        12   Posts for December 31, 2022 | Product Hunt | ...
# 6603        13   Posts for December 31, 2022 | Product Hunt | ...
# 6604        14   Posts for December 31, 2022 | Product Hunt | ...
# 6605        15   Posts for December 31, 2022 | Product Hunt | ...
# 6606        16   Posts for December 31, 2022 | Product Hunt | ...
#
# [6607 rows x 9 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  6607 non-null   object
#  1   upvotes       6607 non-null   object
#  2   category      6607 non-null   object
#  3   tagline       6607 non-null   object
#  4   comments      6607 non-null   object
#  5   image link    4666 non-null   object
#  6   pricing       6607 non-null   object
#  7   position      6607 non-null   int64
#  8   date          6607 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 464.7+ KB

# %%
final_df.to_csv('productHunt2022_scrapingdata.csv', index= False)
